# %%
import pandas as pd
import requests
import json
from pathlib import Path

# %%
df = pd.read_excel("goud_master_experiment.xlsx")
df.head()
# Out:
#                  track_id       track_name            artist_name   owner  \
# 0  0QxCLD4xJlE8vv0Cvrb8TO          '74-'75           The Connells  Astrid
# 1  0IR503DQ7KTbH3MoOQGCJu  10 Stories Down  Michelle Featherstone  Astrid
# 2  0CZ8lquoTX2Dkg7Ak2inwA             1950          King Princess  Astrid
# 3  530iu5ZbzPX8KFLMs7qSK2             1983       Stefano Guzzetti  Astrid
# 4  7129iqBafaphfc3WPCGC0L          7 Years           Lukas Graham  Astrid
#
#   album_name playlist_name
# 0        NaN           NaN
# 1  Blue Bike    Dear Diary
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN
