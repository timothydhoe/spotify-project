# %%
from datetime import datetime, timedelta
from dateutil import rrule

# %%
moment = 30

d1 = datetime(2026, 1, 12)
d2 = datetime(2026, 6, 15)

monday1 = (d1 - timedelta(days=d1.weekday()))
monday2 = (d2 - timedelta(days=d2.weekday()))

weeks = (monday2 - monday1).days / 7

total_effort = weeks*moment//60

print('Weeks:', weeks)
print(f'Total effort: {total_effort} hours')
# Out:
# Weeks: 22.0
# Total effort: 11.0 hours

# %%
def weeks_between(start_date, end_date):
    weeks = rrule.rrule(rrule.WEEKLY, dtstart=start_date, until=end_date)
    return weeks.count()

weeks_between(12-1-2026, 31-5-2026)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       2     weeks = rrule.rrule(rrule.WEEKLY, dtstart=start_date, until=end_date)
#       3     return weeks.count()
# ----> 5 weeks_between(12-1-2026, 31-5-2026)
#
# Cell In[9], line 2, in weeks_between(start_date, end_date)
#       1 def weeks_between(start_date, end_date):
# ----> 2     weeks = rrule.rrule(rrule.WEEKLY, dtstart=start_date, until=end_date)
#       3     return weeks.count()
#
# File c:\Users\astri\anaconda3\envs\py313\Lib\site-packages\dateutil\rrule.py:442, in rrule.__init__(self, freq, dtstart, interval, wkst, count, until, bysetpos, bymonth, bymonthday, byyearday, byeaster, byweekno, byweekday, byhour, byminute, bysecond, cache)
#     440         dtstart = datetime.datetime.now().replace(microsecond=0)
#     441 elif not isinstance(dtstart, datetime.datetime):
# --> 442     dtstart = datetime.datetime.fromordinal(dtstart.toordinal())
#     443 else:
#     444     dtstart = dtstart.replace(microsecond=0)
#
# AttributeError: 'int' object has no attribute 'toordinal'
